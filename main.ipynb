# %%
from expense import Expense
from manager import ExpenseManager

manager = ExpenseManager("expenses.csv")

# %%
while True:
    print("\n1. Add Expense")
    print("2. View Expenses")
    print("3. Exit")

    choice = input("Choose: ")

    if choice == "1":
        title = input("Title: ")
        amount = input("Amount: ")
        category = input("Category: ")

        expense = Expense(title, amount, category)
        manager.add_expense(expense)
        print("Added")

    elif choice == "2":
        manager.view_expenses()

    elif choice == "3":
        break
# Out:
# 1. Add Expense
# 2. View Expenses
# 3. Exit
# Choose:  1
# Title:  Tea
# Amount:  20
# Category:  Food
# Added
#
# 1. Add Expense
# 2. View Expenses
# 3. Exit
# Choose:  2
# ['Title', 'Amount', 'CategoryTea', '20', 'Food']
#
# 1. Add Expense
# 2. View Expenses
# 3. Exit
# Choose:  MOMO
# 1. Add Expense
# 2. View Expenses
# 3. Exit
# Choose:  1
# Title:  MOMO
# Amount:  40
# Category:  FOOD
# Added
#
# 1. Add Expense
# 2. View Expenses
# 3. Exit
